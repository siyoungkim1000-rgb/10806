# %% [markdown]
# <a href="https://colab.research.google.com/github/siyoungkim1000-rgb/10806/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 6
b = 1.5
c = 1 + 2j
print(a, type(a))
print(b, type(b))
print(c, type(c))
print(a + 1, type(a + 1))
print(a / b, type(a / b))
print(a / 2, type(a / 2))
print(a // 2, type(a + 1))
# Out:
# 6 <class 'int'>
# 1.5 <class 'float'>
# (1+2j) <class 'complex'>
# 7 <class 'int'>
# 4.0 <class 'float'>
# 3.0 <class 'float'>
# 3 <class 'int'>

# %%
a = True
b = True
print(a, type(a))
print(b, type(b))
print(10<20, type(10<20))
print(10>20, type(10>20))
# Out:
# True <class 'bool'>
# True <class 'bool'>
# True <class 'bool'>
# False <class 'bool'>

# %%
a = 'Hello'
b = ''
c = 10
d = 0
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
# Out:
# True
# False
# True
# False

# %%
a = 'hello'
b = 'would'
print(a + b)
print(a * 3)
print(a < b)
print('h' in a)
print('wor' not in b)
# Out:
# hellowould
# hellohellohello
# True
# True
# True

# %%
a = 'Hello python'
print(a[0])
print(a[6])
print(a[-1])
# Out:
# H
# p
# n

# %%
a = 'Hello python '
print(a(0:5))
print(a(6:))
print(a(:5))
print(a(6:-4))
print(a(0:9:2))
# Out:
#   File "/tmp/ipykernel_2164/4219837442.py", line 2
#     print(a(0:5))
#              ^
# SyntaxError: invalid syntax

# %%
jumin = input(87)
