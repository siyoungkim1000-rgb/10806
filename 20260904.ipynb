# %% [markdown]
# <a href="https://colab.research.google.com/github/siyoungkim1000-rgb/10806/blob/main/20260904.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = input('이름:')
b = input('나이:')
print (a,'님 안녕하세요?')
print(20-int(b),'년 후면 20살이시네요!')
# Out:
# 이름:김시영
# 나이:17
# 김시영 님 안녕하세요?
# 3 년 후면 20살이시네요!

# %%
print(7/3)
print(7//3)
print(7%3)
# Out:
# 2.3333333333333335
# 2
# 1

# %%
sec = int(input('시간을 초 단위로 입력하세요:'))
minutes = sec // 60
seconds = sec % 60
print(f'(minutes)qns (seconds)초')
# Out:
# 시간을 초 단위로 입력하세요:1초
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3119/4170633791.py in <cell line: 0>()
# ----> 1 sec = int(input('시간을 초 단위로 입력하세요:'))
#       2 minutes = sec // 60
#       3 seconds = sec % 60
#       4 print(f'(minutes)qns (seconds)초')
#
# ValueError: invalid literal for int() with base 10: '1초'
