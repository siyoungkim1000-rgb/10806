# %% [markdown]
# <a href="https://colab.research.google.com/github/siyoungkim1000-rgb/10806/blob/main/20260902_lpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("안녕하세요")

print("1)")
# Out:
# 안녕하세요
# 1)

# %%
print("재미있는 프로그래밍")
print(3+7)
print("3+7")
print(10,20,30,'정보','프로그래밍')
# Out:
# 재미있는 프로그래밍
# 10
# 3+7
# 10 20 30 정보 프로그래밍

# %%
print('한양과학기술고등학교','1학년', '홍길동')
print('체질량 지수(BMI):',)
# Out:
# 한양과학기술고등학교 1학년 홍길동
# 체질량 지수(BMI):

# %%
print('동해 물과 ₩ 백두산₩'이)
print('마르고 닳도록')
print('하느님이 보우하사 ₩n우리나라 만세')
print('무궁화 삼천리', end = '-')
print('화려 강상')
print('대한 사람, "대대한으로 )

# %%
print('######################')

print('[한양과학기술고등학교 학생증]')

print('•학번 : 10806')
print('•성명 : 홍길동')
print('•소속 :스마트전자과')

print('위 사람은 본 학교의 학생임을 증명함.')

print('######################')
# Out:
# ######################
# [한양과학기술고등학교 학생증]
# •학번 : 10806
# •성명 : 홍길동
# •소속 :스마트전자과
# 위 사람은 본 학교의 학생임을 증명함.
# ######################

# %%
c = 90
d = 3.141592
print('직각은 %d도,원주율은 %0.2f 입니다.'%(c,d))
# Out:
# 직각은 90도,원주율은 3.14 입니다.
